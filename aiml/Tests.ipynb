# %%
# %attachments
# Out:
#   Cluster ID  Training Cluster    ML Engine
# ------------  ------------------  -----------
#           26  tensorflow          dist_tf

# %%
# %authenticate 26 -s
# Out:
#  ····································
# Session ID authenticated!

# %%
# %train 26 -j //bd-fs-mnt/project_repo/code/test.py -gpw 2 -nw 2
# Out:
# {'message': 'Submitted batch job 10', 'job_id': '10', 'output': 'http://hpecp-59.hpecplocal:8888/job/10'}

# %%
# %logs?
# Out:
# Docstring:
# ::
#
#   %Usage: "%logs <cluster Id> -url <url>"
#
# The command "%logs" is used to fetch the logs of the submitted job. The logs takes cluster id and --url argument which is a url of the logs
#
# optional arguments:
#   -h, --help  show this help message and exit
#
# log command:
#   {26}        Enter log command
#     26        26 is the cluster Id for cluster tensorflow
#
# %logs 1 --url <url>
# File:      /opt/miniconda/lib/python3.8/site-packages/IPython/extensions/bluedatamagic.py

# %%
# %logs 26 --url http://hpecp-59.hpecplocal:8888/job/10
# Out:
# {'job': {'job_id': 10, 'status': 'COMPLETED', 'links': {'all_jobs': {'href': '/api/v2/jobs'}}, 'username': 'dev1', 'output': '2020-10-22 04:00:55.661619: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcuda.so.1\n2020-10-22 04:00:55.681396: E tensorflow/stream_executor/cuda/cuda_driver.cc:313] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected\n2020-10-22 04:00:55.681471: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:156] kernel driver does not appear to be running on this host (hpecp-60.hpecplocal): /proc/driver/nvidia/version does not exist\n2020-10-22 04:00:55.682278: I tensorflow/core/platform/cpu_feature_guard.cc:143] Your CPU supports instructions that this TensorFlow binary was not compiled to use: SSE4.1 SSE4.2 AVX AVX2 AVX512F FMA\n2020-10-22 04:00:55.691054: I tensorflow/core/platform/profile_utils/cpu_utils.cc:102] CPU Frequency: 2095074999 Hz\n2020-10-22 04:00:55.691236: I tensorfl
# ...

# %%
# !whoami
# !hdfs
# !id
# !hadoop
# !conda list
# Out:
# dev1
# Usage: hdfs [OPTIONS] SUBCOMMAND [SUBCOMMAND OPTIONS]
#
#   OPTIONS is none or any of:
#
# --buildpaths                       attempt to add class files from build tree
# --config dir                       Hadoop config directory
# --daemon (start|status|stop)       operate on a daemon
# --debug                            turn on shell script debug mode
# --help                             usage information
# --hostnames list[,of,host,names]   hosts to use in worker mode
# --hosts filename                   list of hosts to use in worker mode
# --loglevel level                   set the log4j level for this command
# --workers                          turn on worker mode
#
#   SUBCOMMAND is one of:
#
#
#     Admin Commands:
#
# cacheadmin           configure the HDFS cache
# crypto               configure HDFS encryption zones
# debug                run a Debug Admin to execute HDFS debug commands
# dfsadmin             run a DFS admin client
# ...

# %%
import tensorflow
import seaborn
import statsmodels
import sklearn
import bokeh
import hyperopt
import lightgbm
import torch
import torchvision
import theano
import xgboost
import plotly
import tabulate
import sklearn
import sudospawner
import gast
import scipy
import matplotlib
import pandas
import apache_beam
import keras
import numpy
import tensorflow_data_validation
import tensorflow_transform
import tensorflow_metadata
import tensorflow_model_analysis
import flask
import tornado
# Out:
# WARNING (theano.tensor.blas): Using NumPy C-API based implementation for BLAS functions.

# %%
# !hdfs dfs -ls dtap://TenantStorage/
